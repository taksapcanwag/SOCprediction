# %%
# Import modules
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import tensorflow as tf
import os
import datetime
import IPython
import IPython.display
import matplotlib as mpl
import seaborn as sns
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
import rasterio
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import random
import math
import pdb

print("tf version", tf. __version__)
# Out:
# 2023-07-06 11:21:36.666825: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-06 11:21:36.669380: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-06 11:21:36.719190: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-06 11:21:36.720254: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 11:21:37.824016: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tf version 2.12.0

# %%
# Set the working directory
os.getcwd()
os.chdir('/home/shoyo/Desktop')

# %%
# Set seed
seed = 42
def set_seed(seed=42):
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)
  # tf.experimental.numpy.random.seed(seed)
  # tf.compat.v1.get_seed(seed)
  # tf.compat.v1.set_random_seed(seed)
  os.environ['PYTHONHASHSEED'] = str(seed)
  os.environ['TF_DETERMINISTIC_OPS'] = '1'
  os.environ['CUDA_VISIBLE_DEVICES'] = " "
set_seed(42)

# from keras import backend as K
# session_conf = tf.ConfigProto(
#       intra_op_parallelism_threads=1,
#       inter_op_parallelism_threads=1)
# #Force Tensorflow to use a single thread
# sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
# K.set_session(sess)

tf.config.experimental.enable_op_determinism()

# %%
# Load dataset
csv_path = os.getcwd() + '/SOC600to1400.csv'
df1 = pd.read_csv(csv_path)
df2 = df1[ (df1.EVI<-1) | (df1.EVI>1) ]

df = pd.DataFrame(columns=df1.columns)
for i in range(len(df1)):
    lat = df1.loc[i, 'latitude']
    lon = df1.loc[i, 'longitude']
    if not ((df2['latitude'] == lat) & (df2['longitude'] == lon)).any():
        # df = pd.concat([df, df1.loc[i]]) 
        df.loc[len(df)] = df1.iloc[i]
        # df = df.append(df1.loc[i]) 

df = df.drop(columns=['latitude', 'longitude', 'year', 'LC', 'site', 'siteid'])
df['temp'] = df['temp']*0.02
df
# Out:
#           SOC  elev     slope      aspect  roughness       twi     SR_B2
# 0     12.3442  1241       0.0  208.339081   3.538936  1.673863  0.299345  \
# 1     12.3442  1241       0.0  208.339081   3.538936  1.673863  0.323682
# 2     12.3442  1241       0.0  208.339081   3.538936  1.673863  0.272285
# 3     12.3442  1241       0.0  208.339081   3.538936  1.673863   0.07709
# 4     12.3442  1241       0.0  208.339081   3.538936  1.673863  0.135472
# ...       ...   ...       ...         ...        ...       ...       ...
# 3975  7.91165   933  3.818729   58.208199  11.131647 -0.021206  0.193016
# 3976  7.91165   933  3.818729   58.208199  11.131647 -0.021206  0.165942
# 3977  7.91165   933  3.818729   58.208199  11.131647 -0.021206  0.739592
# 3978  7.91165   933  3.818729   58.208199  11.131647 -0.021206   0.10107
# 3979  7.91165   933  3.818729   58.208199  11.131647 -0.021206   0.05289
#
#          SR_B3     SR_B4     SR_B5     SR_B6     SR_B7       EVI        VV
# 0     0.318458  0.313535   0.47573  0.323572  0.266317  0.158519  0.087021  \
# 1     0.350743  0.341915   0.50521  0.262082  0.237772  0.332121  0.089803
# 2     0.303731  0.317302  0.470313  0.215443  0.214301  0.264617  0.113608
# 3     0.133933  0.156812  0.230595  0.243795  0.200153  0.108398  0.050267
# 4      0.17367  0.194433   0.32657   0.28422  0.236865   0.16665  0.049323
# ...        ...       ...       ...       ...       ...       ...       ...
# 3975  0.233854  0.258783  0.339564  0.315433  0.242668  0.152299  0.117782
# 3976  0.212431  0.243438  0.334408    0.3005  0.258398   0.13589  0.132094
# 3977  0.708847  0.709013  0.735962   0.23703  0.244647  0.197731  0.119991
# 3978  0.160607  0.172928  0.325195  0.231008   0.20843  0.230066  0.128847
# 3979  0.124747  0.147627   0.25661  0.265685  0.232987  0.168679  0.143135
#
#             VH     VV/VH       prec        temp
# 0     0.027682  3.143623  11.357198  307.367368
# 1     0.025089  3.579326  10.001375  309.193679
# 2     0.024506   4.63591  13.207593  305.738129
# 3     0.010047  5.003065    8.30924  310.411518
# 4     0.010233  4.819805   7.434655  309.301705
# ...        ...       ...        ...         ...
# 3975  0.032872  3.583099   5.681763  313.016135
# 3976  0.037693  3.504499   7.638311  311.110654
# 3977   0.03305   3.63056   6.670352  311.589897
# 3978   0.03729   3.45525    9.09449  308.674743
# 3979  0.034396   4.16135   4.066809  311.740204
#
# [3980 rows x 18 columns]

# %%
# Shuffle and scale the data
# df = df.sample(frac=1, random_state=42)
scaler = MinMaxScaler()
n = len(df)

# train_df = scaler.fit_transform(df[0:int(n*0.8)])
# val_df = scaler.transform(df[int(n*0.8):int(n*0.9)])
# test_df = scaler.transform(df[int(n*0.9):])
train_df = scaler.fit_transform(df[:3185])
val_df = scaler.transform(df[3185:3500])
test_df = scaler.transform(df[3500:])
max = np.max(df[:3185].SOC)
min = np.min(df[:3185].SOC)

Xtrain = train_df[:,1:]
Ytrain = train_df[:,0]
# [::5]

Xval = val_df[:,1:]
Yval = val_df[:,0]
# [::5]

Xtest = test_df[:,1:]
Ytest = test_df[:,0]
# [::5]

# Reshape it to be (n_data, time_step, feature)
Xtrain = np.reshape(Xtrain, (int(Xtrain.shape[0]/5), 5, Xtrain.shape[1]))
Xval = np.reshape(Xval, (int(Xval.shape[0]/5), 5, Xval.shape[1]))
Xtest = np.reshape(Xtest, (int(Xtest.shape[0]/5), 5, Xtest.shape[1]))

# Reshape it to be (n_data, time_step)
Ytrain = np.reshape(Ytrain, (int(Ytrain.shape[0]/5), 5))
Yval = np.reshape(Yval, (int(Yval.shape[0]/5), 5))
Ytest = np.reshape(Ytest, (int(Ytest.shape[0]/5),5))

# %%
# Show metadsata of the dataset
df.apply(['mean', 'median', 'max', 'min', 'std', 'skew', 'count']).transpose()
# Out:
#                  mean      median          max         min         std
# SOC         10.841766    8.088325    91.416900    2.118900   10.584258  \
# elev       832.179648  956.000000  2004.000000    0.000000  512.121498
# slope        4.931380    2.844062    42.718117    0.000000    6.396783
# aspect     177.230573  173.564682   359.977112    0.032219  108.925980
# roughness   14.454138    5.205354   157.365005    0.288789   23.881823
# twi          0.420232    0.048702     9.095262   -3.766251    2.138266
# SR_B2        0.237874    0.189263     0.969795    0.002620    0.179156
# SR_B3        0.278858    0.240419     0.963333    0.033406    0.153769
# SR_B4        0.295413    0.262282     0.958135    0.028222    0.151137
# SR_B5        0.432829    0.419327     0.934045    0.095735    0.113961
# SR_B6        0.329880    0.322418     0.695978    0.088365    0.085082
# SR_B7        0.254811    0.250395     0.550530    0.057455    0.065593
# EVI          0.211197    0.202979     0.510182   -0.452823    0.083456
# VV           0.110695    0.095081     9.562417    0.008218    0.164983
# VH           0.027067    0.022991     3.638598    0.001052    0.059802
# VV/VH        4.664005    4.225826    23.819882    1.891884    1.788593
# prec        13.707086   12.002974    41.471737    2.085718    7.587817
# temp       307.697234  308.630083   317.087143  295.429836    4.952805
#
#                 skew   count
# SOC         3.851447  3980.0
# elev       -0.245717  3980.0
# slope       2.785089  3980.0
# aspect      0.079549  3980.0
# roughness   2.917422  3980.0
# twi         1.227431  3980.0
# SR_B2       0.956346  3980.0
# SR_B3       0.942502  3980.0
# SR_B4       0.855335  3980.0
# SR_B5       0.598727  3980.0
# SR_B6       0.336086  3980.0
# SR_B7       0.219774  3980.0
# EVI         0.132817  3980.0
# VV         47.472175  3980.0
# VH         55.412888  3980.0
# VV/VH       2.995183  3980.0
# prec        1.092910  3980.0
# temp       -0.386232  3980.0

# %%
# Show the value ranes of the dataset
df_std = pd.DataFrame(train_df).melt(var_name='Column', value_name='Normalized')
plt.figure(figsize=(12, 6))
ax = sns.violinplot(x='Column', y='Normalized', data=df_std)
_ = ax.set_xticklabels(df.keys(), rotation=90)

# %%
# Hyperparameter tuning using validation dataset
# initializer = tf.keras.initializers.GlorotUniform(seed=42)
batch_size = [128, 256]
units = [32, 64, 128, 256]
units_dense = 1
lr = [0.05, 0.01, 0.005]
epochs = 200
info = pd.DataFrame(columns=['batchsize', 'unit', 'learningrate', 'model', 'rmse', 'r2'])
i = 0

for batchSize in batch_size:
    for unit in units:
        for learningRate in lr:

            model1 = tf.keras.models.Sequential([
                tf.keras.layers.LSTM(unit, input_shape=(None, Xtrain.shape[2])),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.Dense(units_dense, activation='linear')])
            
            model2 = tf.keras.models.Sequential([
                tf.keras.layers.LSTM(unit, input_shape=(None, Xtrain.shape[2]), return_sequences=True),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.LSTM(int(unit/2), return_sequences=False),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.Dense(units_dense, activation='linear')])

            model3 = tf.keras.models.Sequential([
                tf.keras.layers.LSTM(unit, input_shape=(None, Xtrain.shape[2]), return_sequences=True),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.LSTM(int(unit/2), return_sequences=True),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.LSTM(int(unit/4), return_sequences=False),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.Dense(units_dense, activation='linear')
            ])

            model4 = tf.keras.models.Sequential([
                tf.keras.layers.LSTM(unit, input_shape=(None, Xtrain.shape[2]), return_sequences=True),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.LSTM(int(unit/2), return_sequences=True),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.LSTM(int(unit/4), return_sequences=True),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.LSTM(int(unit/8), return_sequences=False),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.Dense(units_dense, activation='linear')
            ])
            
            for j in range(4):
                model = [model1, model2, model3, model4][j]
                
                print(i)

                model.compile(loss=tf.keras.losses.MeanSquaredError(),
                    optimizer=tf.keras.optimizers.Adam(learning_rate=learningRate),
                    metrics=[tf.keras.metrics.MeanAbsoluteError(), 
                            tf.keras.metrics.RootMeanSquaredError()
                            ])

                # tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='LSTM', update_freq='epoch', profile_batch=0)
                early_stopping = tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True, monitor='val_loss')

                history = model.fit(Xtrain, Ytrain, 
                                    epochs=epochs, 
                                    batch_size=batchSize,
                                    validation_data=(Xval, Yval), 
                                    callbacks=[early_stopping]
                                    )
                
                Ypred = model.predict(Xval)
                Yval = np.array([sublist[::5] for sublist in Yval])
                Ypred = Ypred * (max-min) + min
                Yval = Yval * (max-min) + min

                mse = mean_squared_error(Yval, Ypred)
                print("RMSE", math.sqrt(mse))
                mae = mean_absolute_error(Yval, Ypred)
                print("MAE", mae)
                R_square = r2_score(Yval, Ypred) 
                print('Coefficient of Determination', R_square) 

                addCol = pd.Series( [ batchSize, unit, learningRate, str(j+1), math.sqrt(mse), R_square ],
                       index=info.columns 
                       )
                
                info.loc[i] = addCol

                i=i+1

print(info)
info.to_csv(os.getcwd() + '/info.csv', index=False)
# Out:
# 2023-07-06 12:16:48.681407: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:48.683967: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:48.685450: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:16:48.984548: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:48.986698: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:48.988090: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:16:49.242204: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:49.243630: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:49.245325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:16:49.500553: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:49.502522: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:49.503817: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:16:49.732817: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:49.734966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:49.736250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:16:49.970457: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:49.971901: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:49.973449: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:16:50.233765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:50.235703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:50.237007: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:16:50.464934: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:50.466798: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:50.468012: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:16:50.702737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:50.704666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:50.706382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 0
# Epoch 1/200
# 2023-07-06 12:16:50.944462: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:50.946519: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:50.947838: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:16:51.048446: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [637,5]
# 	 [[{{node Placeholder/_11}}]]
# 2023-07-06 12:16:51.048744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [637,5]
# 	 [[{{node Placeholder/_11}}]]
# 2023-07-06 12:16:51.280641: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:51.282834: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:51.284300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:16:52.030757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:52.032466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:52.034454: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/5 [=====>........................] - ETA: 8s - loss: 1.2642 - mean_absolute_error: 0.8827 - root_mean_squared_error: 1.1244
# 2023-07-06 12:16:53.379978: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [63,5]
# 	 [[{{node Placeholder/_11}}]]
# 2023-07-06 12:16:53.380340: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [63,5]
# 	 [[{{node Placeholder/_11}}]]
# 2023-07-06 12:16:53.633087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:16:53.635280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:16:53.636715: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 5/5 [==============================] - 3s 175ms/step - loss: 2.3708 - mean_absolute_error: 1.0542 - root_mean_squared_error: 1.5398 - val_loss: 0.0384 - val_mean_absolute_error: 0.1616 - val_root_mean_squared_error: 0.1960
# Epoch 2/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2493 - mean_absolute_error: 0.3527 - root_mean_squared_error: 0.4993 - val_loss: 0.0075 - val_mean_absolute_error: 0.0527 - val_root_mean_squared_error: 0.0868
# Epoch 3/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1058 - mean_absolute_error: 0.2387 - root_mean_squared_error: 0.3252 - val_loss: 0.0164 - val_mean_absolute_error: 0.0936 - val_root_mean_squared_error: 0.1280
# Epoch 4/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0587 - mean_absolute_error: 0.1826 - root_mean_squared_error: 0.2423 - val_loss: 0.0087 - val_mean_absolute_error: 0.0629 - val_root_mean_squared_error: 0.0931
# Epoch 5/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0439 - mean_absolute_error: 0.1589 - root_mean_squared_error: 0.2095 - val_loss: 0.0077 - val_mean_absolute_error: 0.0671 - val_root_mean_squared_error: 0.0878
# Epoch 6/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0294 - mean_absolute_error: 0.1258 - root_mean_squared_error: 0.1715 - val_loss: 0.0071 - val_mean_absolute_error: 0.0521 - val_root_mean_squared_error: 0.0844
# Epoch 7/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0294 - mean_absolute_error: 0.1232 - root_mean_squared_error: 0.1716 - val_loss: 0.0076 - val_mean_absolute_error: 0.0662 - val_root_mean_squared_error: 0.0874
# Epoch 8/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0217 - mean_absolute_error: 0.1062 - root_mean_squared_error: 0.1473 - val_loss: 0.0080 - val_mean_absolute_error: 0.0566 - val_root_mean_squared_error: 0.0894
# Epoch 9/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0208 - mean_absolute_error: 0.0953 - root_mean_squared_error: 0.1443 - val_loss: 0.0078 - val_mean_absolute_error: 0.0629 - val_root_mean_squared_error: 0.0886
# Epoch 10/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0198 - mean_absolute_error: 0.0993 - root_mean_squared_error: 0.1406 - val_loss: 0.0076 - val_mean_absolute_error: 0.0602 - val_root_mean_squared_error: 0.0875
# Epoch 11/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0169 - mean_absolute_error: 0.0834 - root_mean_squared_error: 0.1300 - val_loss: 0.0074 - val_mean_absolute_error: 0.0581 - val_root_mean_squared_error: 0.0861
# Epoch 12/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0149 - mean_absolute_error: 0.0803 - root_mean_squared_error: 0.1222 - val_loss: 0.0079 - val_mean_absolute_error: 0.0675 - val_root_mean_squared_error: 0.0888
# Epoch 13/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0141 - mean_absolute_error: 0.0741 - root_mean_squared_error: 0.1189 - val_loss: 0.0077 - val_mean_absolute_error: 0.0549 - val_root_mean_squared_error: 0.0878
# Epoch 14/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0133 - mean_absolute_error: 0.0720 - root_mean_squared_error: 0.1153 - val_loss: 0.0077 - val_mean_absolute_error: 0.0659 - val_root_mean_squared_error: 0.0877
# Epoch 15/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0133 - mean_absolute_error: 0.0715 - root_mean_squared_error: 0.1152 - val_loss: 0.0073 - val_mean_absolute_error: 0.0554 - val_root_mean_squared_error: 0.0852
# Epoch 16/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0120 - mean_absolute_error: 0.0691 - root_mean_squared_error: 0.1096 - val_loss: 0.0073 - val_mean_absolute_error: 0.0622 - val_root_mean_squared_error: 0.0854
# Epoch 17/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0122 - mean_absolute_error: 0.0665 - root_mean_squared_error: 0.1103 - val_loss: 0.0070 - val_mean_absolute_error: 0.0567 - val_root_mean_squared_error: 0.0837
# Epoch 18/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0121 - mean_absolute_error: 0.0671 - root_mean_squared_error: 0.1100 - val_loss: 0.0070 - val_mean_absolute_error: 0.0583 - val_root_mean_squared_error: 0.0838
# Epoch 19/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0128 - mean_absolute_error: 0.0656 - root_mean_squared_error: 0.1132 - val_loss: 0.0070 - val_mean_absolute_error: 0.0560 - val_root_mean_squared_error: 0.0837
# Epoch 20/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0117 - mean_absolute_error: 0.0679 - root_mean_squared_error: 0.1083 - val_loss: 0.0074 - val_mean_absolute_error: 0.0642 - val_root_mean_squared_error: 0.0861
# Epoch 21/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0113 - mean_absolute_error: 0.0619 - root_mean_squared_error: 0.1064 - val_loss: 0.0070 - val_mean_absolute_error: 0.0545 - val_root_mean_squared_error: 0.0839
# Epoch 22/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0114 - mean_absolute_error: 0.0644 - root_mean_squared_error: 0.1068 - val_loss: 0.0071 - val_mean_absolute_error: 0.0609 - val_root_mean_squared_error: 0.0843
# Epoch 23/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0108 - mean_absolute_error: 0.0609 - root_mean_squared_error: 0.1040 - val_loss: 0.0069 - val_mean_absolute_error: 0.0547 - val_root_mean_squared_error: 0.0832
# Epoch 24/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0113 - mean_absolute_error: 0.0648 - root_mean_squared_error: 0.1064 - val_loss: 0.0070 - val_mean_absolute_error: 0.0587 - val_root_mean_squared_error: 0.0835
# Epoch 25/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0105 - mean_absolute_error: 0.0585 - root_mean_squared_error: 0.1024 - val_loss: 0.0069 - val_mean_absolute_error: 0.0567 - val_root_mean_squared_error: 0.0830
# Epoch 26/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0107 - mean_absolute_error: 0.0599 - root_mean_squared_error: 0.1032 - val_loss: 0.0070 - val_mean_absolute_error: 0.0605 - val_root_mean_squared_error: 0.0839
# Epoch 27/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0105 - mean_absolute_error: 0.0610 - root_mean_squared_error: 0.1027 - val_loss: 0.0068 - val_mean_absolute_error: 0.0556 - val_root_mean_squared_error: 0.0826
# Epoch 28/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0103 - mean_absolute_error: 0.0579 - root_mean_squared_error: 0.1016 - val_loss: 0.0068 - val_mean_absolute_error: 0.0571 - val_root_mean_squared_error: 0.0827
# Epoch 29/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0104 - mean_absolute_error: 0.0579 - root_mean_squared_error: 0.1019 - val_loss: 0.0069 - val_mean_absolute_error: 0.0577 - val_root_mean_squared_error: 0.0828
# Epoch 30/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0105 - mean_absolute_error: 0.0616 - root_mean_squared_error: 0.1024 - val_loss: 0.0068 - val_mean_absolute_error: 0.0544 - val_root_mean_squared_error: 0.0823
# Epoch 31/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0102 - mean_absolute_error: 0.0572 - root_mean_squared_error: 0.1010 - val_loss: 0.0069 - val_mean_absolute_error: 0.0583 - val_root_mean_squared_error: 0.0828
# Epoch 32/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0106 - mean_absolute_error: 0.0636 - root_mean_squared_error: 0.1029 - val_loss: 0.0068 - val_mean_absolute_error: 0.0567 - val_root_mean_squared_error: 0.0823
# Epoch 33/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0097 - mean_absolute_error: 0.0576 - root_mean_squared_error: 0.0986 - val_loss: 0.0067 - val_mean_absolute_error: 0.0569 - val_root_mean_squared_error: 0.0820
# Epoch 34/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0101 - mean_absolute_error: 0.0626 - root_mean_squared_error: 0.1005 - val_loss: 0.0066 - val_mean_absolute_error: 0.0540 - val_root_mean_squared_error: 0.0815
# Epoch 35/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0101 - mean_absolute_error: 0.0580 - root_mean_squared_error: 0.1005 - val_loss: 0.0068 - val_mean_absolute_error: 0.0585 - val_root_mean_squared_error: 0.0823
# Epoch 36/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0103 - mean_absolute_error: 0.0638 - root_mean_squared_error: 0.1014 - val_loss: 0.0066 - val_mean_absolute_error: 0.0527 - val_root_mean_squared_error: 0.0811
# Epoch 37/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0098 - mean_absolute_error: 0.0578 - root_mean_squared_error: 0.0992 - val_loss: 0.0065 - val_mean_absolute_error: 0.0535 - val_root_mean_squared_error: 0.0805
# Epoch 38/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0099 - mean_absolute_error: 0.0618 - root_mean_squared_error: 0.0996 - val_loss: 0.0065 - val_mean_absolute_error: 0.0544 - val_root_mean_squared_error: 0.0807
# Epoch 39/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0101 - mean_absolute_error: 0.0593 - root_mean_squared_error: 0.1004 - val_loss: 0.0066 - val_mean_absolute_error: 0.0526 - val_root_mean_squared_error: 0.0811
# Epoch 40/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0105 - mean_absolute_error: 0.0629 - root_mean_squared_error: 0.1026 - val_loss: 0.0066 - val_mean_absolute_error: 0.0515 - val_root_mean_squared_error: 0.0815
# Epoch 41/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0101 - mean_absolute_error: 0.0581 - root_mean_squared_error: 0.1006 - val_loss: 0.0065 - val_mean_absolute_error: 0.0561 - val_root_mean_squared_error: 0.0807
# Epoch 42/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0096 - mean_absolute_error: 0.0588 - root_mean_squared_error: 0.0982 - val_loss: 0.0064 - val_mean_absolute_error: 0.0537 - val_root_mean_squared_error: 0.0801
# Epoch 43/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0094 - mean_absolute_error: 0.0578 - root_mean_squared_error: 0.0971 - val_loss: 0.0064 - val_mean_absolute_error: 0.0517 - val_root_mean_squared_error: 0.0802
# Epoch 44/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0094 - mean_absolute_error: 0.0564 - root_mean_squared_error: 0.0972 - val_loss: 0.0065 - val_mean_absolute_error: 0.0562 - val_root_mean_squared_error: 0.0804
# Epoch 45/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0092 - mean_absolute_error: 0.0575 - root_mean_squared_error: 0.0957 - val_loss: 0.0066 - val_mean_absolute_error: 0.0502 - val_root_mean_squared_error: 0.0811
# Epoch 46/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0094 - mean_absolute_error: 0.0600 - root_mean_squared_error: 0.0970 - val_loss: 0.0064 - val_mean_absolute_error: 0.0509 - val_root_mean_squared_error: 0.0798
# Epoch 47/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0085 - mean_absolute_error: 0.0565 - root_mean_squared_error: 0.0920 - val_loss: 0.0064 - val_mean_absolute_error: 0.0505 - val_root_mean_squared_error: 0.0799
# Epoch 48/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0090 - mean_absolute_error: 0.0586 - root_mean_squared_error: 0.0948 - val_loss: 0.0065 - val_mean_absolute_error: 0.0499 - val_root_mean_squared_error: 0.0805
# Epoch 49/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0089 - mean_absolute_error: 0.0568 - root_mean_squared_error: 0.0944 - val_loss: 0.0062 - val_mean_absolute_error: 0.0527 - val_root_mean_squared_error: 0.0786
# Epoch 50/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0089 - mean_absolute_error: 0.0607 - root_mean_squared_error: 0.0944 - val_loss: 0.0071 - val_mean_absolute_error: 0.0510 - val_root_mean_squared_error: 0.0841
# Epoch 51/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0090 - mean_absolute_error: 0.0572 - root_mean_squared_error: 0.0947 - val_loss: 0.0062 - val_mean_absolute_error: 0.0543 - val_root_mean_squared_error: 0.0789
# Epoch 52/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0086 - mean_absolute_error: 0.0619 - root_mean_squared_error: 0.0929 - val_loss: 0.0074 - val_mean_absolute_error: 0.0521 - val_root_mean_squared_error: 0.0858
# Epoch 53/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0084 - mean_absolute_error: 0.0558 - root_mean_squared_error: 0.0917 - val_loss: 0.0061 - val_mean_absolute_error: 0.0528 - val_root_mean_squared_error: 0.0781
# Epoch 54/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0090 - mean_absolute_error: 0.0610 - root_mean_squared_error: 0.0948 - val_loss: 0.0070 - val_mean_absolute_error: 0.0512 - val_root_mean_squared_error: 0.0838
# Epoch 55/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0078 - mean_absolute_error: 0.0554 - root_mean_squared_error: 0.0881 - val_loss: 0.0062 - val_mean_absolute_error: 0.0514 - val_root_mean_squared_error: 0.0786
# Epoch 56/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0080 - mean_absolute_error: 0.0566 - root_mean_squared_error: 0.0896 - val_loss: 0.0066 - val_mean_absolute_error: 0.0501 - val_root_mean_squared_error: 0.0813
# Epoch 57/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0077 - mean_absolute_error: 0.0529 - root_mean_squared_error: 0.0877 - val_loss: 0.0063 - val_mean_absolute_error: 0.0496 - val_root_mean_squared_error: 0.0794
# Epoch 58/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0079 - mean_absolute_error: 0.0566 - root_mean_squared_error: 0.0887 - val_loss: 0.0064 - val_mean_absolute_error: 0.0497 - val_root_mean_squared_error: 0.0803
# Epoch 59/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0073 - mean_absolute_error: 0.0541 - root_mean_squared_error: 0.0857 - val_loss: 0.0062 - val_mean_absolute_error: 0.0498 - val_root_mean_squared_error: 0.0789
# Epoch 60/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0066 - mean_absolute_error: 0.0516 - root_mean_squared_error: 0.0813 - val_loss: 0.0061 - val_mean_absolute_error: 0.0502 - val_root_mean_squared_error: 0.0783
# Epoch 61/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0079 - mean_absolute_error: 0.0528 - root_mean_squared_error: 0.0890 - val_loss: 0.0061 - val_mean_absolute_error: 0.0493 - val_root_mean_squared_error: 0.0779
# Epoch 62/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0082 - mean_absolute_error: 0.0532 - root_mean_squared_error: 0.0904 - val_loss: 0.0065 - val_mean_absolute_error: 0.0498 - val_root_mean_squared_error: 0.0804
# Epoch 63/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0083 - mean_absolute_error: 0.0554 - root_mean_squared_error: 0.0910 - val_loss: 0.0069 - val_mean_absolute_error: 0.0516 - val_root_mean_squared_error: 0.0830
# Epoch 64/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0069 - mean_absolute_error: 0.0502 - root_mean_squared_error: 0.0833 - val_loss: 0.0069 - val_mean_absolute_error: 0.0515 - val_root_mean_squared_error: 0.0829
# Epoch 65/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0080 - mean_absolute_error: 0.0568 - root_mean_squared_error: 0.0896 - val_loss: 0.0068 - val_mean_absolute_error: 0.0522 - val_root_mean_squared_error: 0.0825
# Epoch 66/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0068 - mean_absolute_error: 0.0524 - root_mean_squared_error: 0.0827 - val_loss: 0.0057 - val_mean_absolute_error: 0.0527 - val_root_mean_squared_error: 0.0755
# Epoch 67/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0071 - mean_absolute_error: 0.0531 - root_mean_squared_error: 0.0841 - val_loss: 0.0068 - val_mean_absolute_error: 0.0526 - val_root_mean_squared_error: 0.0824
# Epoch 68/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0069 - mean_absolute_error: 0.0514 - root_mean_squared_error: 0.0828 - val_loss: 0.0057 - val_mean_absolute_error: 0.0531 - val_root_mean_squared_error: 0.0752
# Epoch 69/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0062 - mean_absolute_error: 0.0529 - root_mean_squared_error: 0.0790 - val_loss: 0.0070 - val_mean_absolute_error: 0.0534 - val_root_mean_squared_error: 0.0834
# Epoch 70/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0073 - mean_absolute_error: 0.0528 - root_mean_squared_error: 0.0855 - val_loss: 0.0056 - val_mean_absolute_error: 0.0534 - val_root_mean_squared_error: 0.0749
# Epoch 71/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0069 - mean_absolute_error: 0.0505 - root_mean_squared_error: 0.0828 - val_loss: 0.0069 - val_mean_absolute_error: 0.0527 - val_root_mean_squared_error: 0.0833
# Epoch 72/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0067 - mean_absolute_error: 0.0493 - root_mean_squared_error: 0.0817 - val_loss: 0.0059 - val_mean_absolute_error: 0.0501 - val_root_mean_squared_error: 0.0766
# Epoch 73/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0064 - mean_absolute_error: 0.0491 - root_mean_squared_error: 0.0802 - val_loss: 0.0059 - val_mean_absolute_error: 0.0503 - val_root_mean_squared_error: 0.0768
# Epoch 74/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0063 - mean_absolute_error: 0.0473 - root_mean_squared_error: 0.0793 - val_loss: 0.0058 - val_mean_absolute_error: 0.0502 - val_root_mean_squared_error: 0.0761
# Epoch 75/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0064 - mean_absolute_error: 0.0480 - root_mean_squared_error: 0.0802 - val_loss: 0.0056 - val_mean_absolute_error: 0.0493 - val_root_mean_squared_error: 0.0745
# Epoch 76/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0063 - mean_absolute_error: 0.0508 - root_mean_squared_error: 0.0791 - val_loss: 0.0072 - val_mean_absolute_error: 0.0561 - val_root_mean_squared_error: 0.0848
# Epoch 77/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0073 - mean_absolute_error: 0.0505 - root_mean_squared_error: 0.0855 - val_loss: 0.0059 - val_mean_absolute_error: 0.0501 - val_root_mean_squared_error: 0.0766
# Epoch 78/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0060 - mean_absolute_error: 0.0490 - root_mean_squared_error: 0.0777 - val_loss: 0.0058 - val_mean_absolute_error: 0.0499 - val_root_mean_squared_error: 0.0761
# Epoch 79/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0063 - mean_absolute_error: 0.0513 - root_mean_squared_error: 0.0793 - val_loss: 0.0062 - val_mean_absolute_error: 0.0514 - val_root_mean_squared_error: 0.0788
# Epoch 80/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0068 - mean_absolute_error: 0.0511 - root_mean_squared_error: 0.0824 - val_loss: 0.0058 - val_mean_absolute_error: 0.0501 - val_root_mean_squared_error: 0.0762
# Epoch 81/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0066 - mean_absolute_error: 0.0490 - root_mean_squared_error: 0.0811 - val_loss: 0.0055 - val_mean_absolute_error: 0.0491 - val_root_mean_squared_error: 0.0741
# Epoch 82/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0065 - mean_absolute_error: 0.0495 - root_mean_squared_error: 0.0808 - val_loss: 0.0056 - val_mean_absolute_error: 0.0491 - val_root_mean_squared_error: 0.0751
# Epoch 83/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0064 - mean_absolute_error: 0.0482 - root_mean_squared_error: 0.0799 - val_loss: 0.0058 - val_mean_absolute_error: 0.0500 - val_root_mean_squared_error: 0.0759
# Epoch 84/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0066 - mean_absolute_error: 0.0484 - root_mean_squared_error: 0.0815 - val_loss: 0.0055 - val_mean_absolute_error: 0.0497 - val_root_mean_squared_error: 0.0741
# Epoch 85/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0060 - mean_absolute_error: 0.0473 - root_mean_squared_error: 0.0772 - val_loss: 0.0054 - val_mean_absolute_error: 0.0493 - val_root_mean_squared_error: 0.0736
# Epoch 86/200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0096 - mean_absolute_error: 0.0498 - root_mean_squared_error: 0.0981

# %%
model2 = tf.keras.models.Sequential([
                tf.keras.layers.LSTM(unit, input_shape=(None, Xtrain.shape[2]), return_sequences=True),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.LSTM(int(unit/2), return_sequences=False),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2, seed=seed),
                tf.keras.layers.Dense(units_dense, activation='linear')])
# Out:
# 2023-07-06 12:14:03.635243: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:14:03.637721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:14:03.640161: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 12:14:03.902264: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 12:14:03.904379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 12:14:03.905764: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Define the potential best model and its hyperparameters
batch_size = 128
unit = 64
units_dense = 1
lr = 0.01
epochs = 200
model = model2

# %%
# See the model details
print('train data size', len(train_df))
model.summary()
# Out:
# train data size 3185
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, None, 64)          20992
#
#  batch_normalization (BatchN  (None, None, 64)         256
#  ormalization)
#
#  dropout (Dropout)           (None, None, 64)          0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 33,825
# Trainable params: 33,633
# Non-trainable params: 192
# _________________________________________________________________

# %%
# Train the model
model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
              metrics=[tf.keras.metrics.MeanAbsoluteError(), 
                       tf.keras.metrics.RootMeanSquaredError()
                       ])

# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='LSTM', update_freq='epoch', profile_batch=0)
early_stopping = tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True, monitor='val_loss')

history = model.fit(Xtrain, Ytrain, 
                    epochs=epochs, 
                    batch_size=batch_size,
                    validation_data=(Xval, Yval), 
                    callbacks=[early_stopping]
                    )
# Out:
# Epoch 1/200
# 2023-07-06 11:43:40.225265: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [637,5]
# 	 [[{{node Placeholder/_11}}]]
# 2023-07-06 11:43:40.225617: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [637,5]
# 	 [[{{node Placeholder/_11}}]]
# 2023-07-06 11:43:40.502771: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 11:43:40.505290: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 11:43:40.506962: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 11:43:40.752297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 11:43:40.754481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 11:43:40.755844: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 11:43:41.900151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 11:43:41.903222: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 11:43:41.904700: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 11:43:42.144117: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 11:43:42.146830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 11:43:42.148400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7100 - mean_absolute_error: 0.6504 - root_mean_squared_error: 0.8426
# 2023-07-06 11:43:44.969948: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [63,5]
# 	 [[{{node Placeholder/_11}}]]
# 2023-07-06 11:43:44.970328: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [63,5]
# 	 [[{{node Placeholder/_11}}]]
# 2023-07-06 11:43:45.280665: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 11:43:45.282749: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 11:43:45.284308: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-07-06 11:43:45.532087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-07-06 11:43:45.534436: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-07-06 11:43:45.535904: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 5/5 [==============================] - 6s 309ms/step - loss: 0.6759 - mean_absolute_error: 0.6350 - root_mean_squared_error: 0.8221 - val_loss: 0.0087 - val_mean_absolute_error: 0.0747 - val_root_mean_squared_error: 0.0935
# Epoch 2/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.4009 - mean_absolute_error: 0.4914 - root_mean_squared_error: 0.6331 - val_loss: 0.0188 - val_mean_absolute_error: 0.1255 - val_root_mean_squared_error: 0.1371
# Epoch 3/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2602 - mean_absolute_error: 0.3980 - root_mean_squared_error: 0.5101 - val_loss: 0.0139 - val_mean_absolute_error: 0.0998 - val_root_mean_squared_error: 0.1181
# Epoch 4/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1653 - mean_absolute_error: 0.3212 - root_mean_squared_error: 0.4066 - val_loss: 0.0090 - val_mean_absolute_error: 0.0758 - val_root_mean_squared_error: 0.0948
# Epoch 5/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1388 - mean_absolute_error: 0.2974 - root_mean_squared_error: 0.3725 - val_loss: 0.0092 - val_mean_absolute_error: 0.0780 - val_root_mean_squared_error: 0.0959
# Epoch 6/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1171 - mean_absolute_error: 0.2714 - root_mean_squared_error: 0.3422 - val_loss: 0.0098 - val_mean_absolute_error: 0.0813 - val_root_mean_squared_error: 0.0992
# Epoch 7/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0896 - mean_absolute_error: 0.2344 - root_mean_squared_error: 0.2993 - val_loss: 0.0086 - val_mean_absolute_error: 0.0714 - val_root_mean_squared_error: 0.0927
# Epoch 8/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0725 - mean_absolute_error: 0.2114 - root_mean_squared_error: 0.2693 - val_loss: 0.0083 - val_mean_absolute_error: 0.0688 - val_root_mean_squared_error: 0.0914
# Epoch 9/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0580 - mean_absolute_error: 0.1849 - root_mean_squared_error: 0.2408 - val_loss: 0.0087 - val_mean_absolute_error: 0.0733 - val_root_mean_squared_error: 0.0934
# Epoch 10/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0490 - mean_absolute_error: 0.1751 - root_mean_squared_error: 0.2214 - val_loss: 0.0082 - val_mean_absolute_error: 0.0687 - val_root_mean_squared_error: 0.0908
# Epoch 11/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0342 - mean_absolute_error: 0.1440 - root_mean_squared_error: 0.1850 - val_loss: 0.0079 - val_mean_absolute_error: 0.0675 - val_root_mean_squared_error: 0.0890
# Epoch 12/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0333 - mean_absolute_error: 0.1437 - root_mean_squared_error: 0.1824 - val_loss: 0.0071 - val_mean_absolute_error: 0.0587 - val_root_mean_squared_error: 0.0843
# Epoch 13/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0266 - mean_absolute_error: 0.1265 - root_mean_squared_error: 0.1631 - val_loss: 0.0071 - val_mean_absolute_error: 0.0586 - val_root_mean_squared_error: 0.0842
# Epoch 14/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0231 - mean_absolute_error: 0.1130 - root_mean_squared_error: 0.1520 - val_loss: 0.0072 - val_mean_absolute_error: 0.0597 - val_root_mean_squared_error: 0.0847
# Epoch 15/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0190 - mean_absolute_error: 0.1036 - root_mean_squared_error: 0.1379 - val_loss: 0.0070 - val_mean_absolute_error: 0.0572 - val_root_mean_squared_error: 0.0836
# Epoch 16/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0187 - mean_absolute_error: 0.0994 - root_mean_squared_error: 0.1368 - val_loss: 0.0073 - val_mean_absolute_error: 0.0618 - val_root_mean_squared_error: 0.0856
# Epoch 17/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0155 - mean_absolute_error: 0.0907 - root_mean_squared_error: 0.1247 - val_loss: 0.0068 - val_mean_absolute_error: 0.0564 - val_root_mean_squared_error: 0.0826
# Epoch 18/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0154 - mean_absolute_error: 0.0917 - root_mean_squared_error: 0.1241 - val_loss: 0.0072 - val_mean_absolute_error: 0.0609 - val_root_mean_squared_error: 0.0846
# Epoch 19/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0134 - mean_absolute_error: 0.0807 - root_mean_squared_error: 0.1157 - val_loss: 0.0068 - val_mean_absolute_error: 0.0559 - val_root_mean_squared_error: 0.0823
# Epoch 20/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0115 - mean_absolute_error: 0.0745 - root_mean_squared_error: 0.1071 - val_loss: 0.0070 - val_mean_absolute_error: 0.0590 - val_root_mean_squared_error: 0.0836
# Epoch 21/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0102 - mean_absolute_error: 0.0693 - root_mean_squared_error: 0.1010 - val_loss: 0.0070 - val_mean_absolute_error: 0.0601 - val_root_mean_squared_error: 0.0835
# Epoch 22/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0095 - mean_absolute_error: 0.0672 - root_mean_squared_error: 0.0975 - val_loss: 0.0070 - val_mean_absolute_error: 0.0618 - val_root_mean_squared_error: 0.0838
# Epoch 23/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0096 - mean_absolute_error: 0.0670 - root_mean_squared_error: 0.0977 - val_loss: 0.0067 - val_mean_absolute_error: 0.0585 - val_root_mean_squared_error: 0.0820
# Epoch 24/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0082 - mean_absolute_error: 0.0598 - root_mean_squared_error: 0.0904 - val_loss: 0.0068 - val_mean_absolute_error: 0.0585 - val_root_mean_squared_error: 0.0822
# Epoch 25/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0076 - mean_absolute_error: 0.0596 - root_mean_squared_error: 0.0871 - val_loss: 0.0066 - val_mean_absolute_error: 0.0569 - val_root_mean_squared_error: 0.0809
# Epoch 26/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0084 - mean_absolute_error: 0.0586 - root_mean_squared_error: 0.0915 - val_loss: 0.0064 - val_mean_absolute_error: 0.0556 - val_root_mean_squared_error: 0.0801
# Epoch 27/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0074 - mean_absolute_error: 0.0560 - root_mean_squared_error: 0.0859 - val_loss: 0.0066 - val_mean_absolute_error: 0.0589 - val_root_mean_squared_error: 0.0814
# Epoch 28/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0078 - mean_absolute_error: 0.0544 - root_mean_squared_error: 0.0884 - val_loss: 0.0067 - val_mean_absolute_error: 0.0590 - val_root_mean_squared_error: 0.0818
# Epoch 29/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0071 - mean_absolute_error: 0.0522 - root_mean_squared_error: 0.0845 - val_loss: 0.0065 - val_mean_absolute_error: 0.0566 - val_root_mean_squared_error: 0.0807
# Epoch 30/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0072 - mean_absolute_error: 0.0526 - root_mean_squared_error: 0.0847 - val_loss: 0.0065 - val_mean_absolute_error: 0.0574 - val_root_mean_squared_error: 0.0805
# Epoch 31/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0068 - mean_absolute_error: 0.0514 - root_mean_squared_error: 0.0825 - val_loss: 0.0063 - val_mean_absolute_error: 0.0568 - val_root_mean_squared_error: 0.0795
# Epoch 32/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0062 - mean_absolute_error: 0.0510 - root_mean_squared_error: 0.0787 - val_loss: 0.0063 - val_mean_absolute_error: 0.0568 - val_root_mean_squared_error: 0.0796
# Epoch 33/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0070 - mean_absolute_error: 0.0505 - root_mean_squared_error: 0.0838 - val_loss: 0.0062 - val_mean_absolute_error: 0.0560 - val_root_mean_squared_error: 0.0790
# Epoch 34/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0057 - mean_absolute_error: 0.0497 - root_mean_squared_error: 0.0757 - val_loss: 0.0062 - val_mean_absolute_error: 0.0567 - val_root_mean_squared_error: 0.0789
# Epoch 35/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0060 - mean_absolute_error: 0.0479 - root_mean_squared_error: 0.0774 - val_loss: 0.0062 - val_mean_absolute_error: 0.0566 - val_root_mean_squared_error: 0.0788
# Epoch 36/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0062 - mean_absolute_error: 0.0483 - root_mean_squared_error: 0.0785 - val_loss: 0.0061 - val_mean_absolute_error: 0.0551 - val_root_mean_squared_error: 0.0779
# Epoch 37/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0068 - mean_absolute_error: 0.0494 - root_mean_squared_error: 0.0825 - val_loss: 0.0061 - val_mean_absolute_error: 0.0557 - val_root_mean_squared_error: 0.0778
# Epoch 38/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0067 - mean_absolute_error: 0.0486 - root_mean_squared_error: 0.0820 - val_loss: 0.0058 - val_mean_absolute_error: 0.0522 - val_root_mean_squared_error: 0.0760
# Epoch 39/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0072 - mean_absolute_error: 0.0510 - root_mean_squared_error: 0.0850 - val_loss: 0.0059 - val_mean_absolute_error: 0.0538 - val_root_mean_squared_error: 0.0768
# Epoch 40/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0051 - mean_absolute_error: 0.0473 - root_mean_squared_error: 0.0715 - val_loss: 0.0058 - val_mean_absolute_error: 0.0516 - val_root_mean_squared_error: 0.0759
# Epoch 41/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0047 - mean_absolute_error: 0.0456 - root_mean_squared_error: 0.0686 - val_loss: 0.0060 - val_mean_absolute_error: 0.0544 - val_root_mean_squared_error: 0.0772
# Epoch 42/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0059 - mean_absolute_error: 0.0465 - root_mean_squared_error: 0.0765 - val_loss: 0.0056 - val_mean_absolute_error: 0.0506 - val_root_mean_squared_error: 0.0750
# Epoch 43/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0048 - mean_absolute_error: 0.0451 - root_mean_squared_error: 0.0693 - val_loss: 0.0056 - val_mean_absolute_error: 0.0520 - val_root_mean_squared_error: 0.0750
# Epoch 44/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0066 - mean_absolute_error: 0.0477 - root_mean_squared_error: 0.0814 - val_loss: 0.0057 - val_mean_absolute_error: 0.0527 - val_root_mean_squared_error: 0.0754
# Epoch 45/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0053 - mean_absolute_error: 0.0454 - root_mean_squared_error: 0.0725 - val_loss: 0.0057 - val_mean_absolute_error: 0.0503 - val_root_mean_squared_error: 0.0752
# Epoch 46/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0061 - mean_absolute_error: 0.0477 - root_mean_squared_error: 0.0783 - val_loss: 0.0057 - val_mean_absolute_error: 0.0518 - val_root_mean_squared_error: 0.0754
# Epoch 47/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0057 - mean_absolute_error: 0.0473 - root_mean_squared_error: 0.0757 - val_loss: 0.0052 - val_mean_absolute_error: 0.0488 - val_root_mean_squared_error: 0.0724
# Epoch 48/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0058 - mean_absolute_error: 0.0468 - root_mean_squared_error: 0.0763 - val_loss: 0.0053 - val_mean_absolute_error: 0.0508 - val_root_mean_squared_error: 0.0731
# Epoch 49/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0047 - mean_absolute_error: 0.0438 - root_mean_squared_error: 0.0684 - val_loss: 0.0050 - val_mean_absolute_error: 0.0476 - val_root_mean_squared_error: 0.0706
# Epoch 50/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0045 - mean_absolute_error: 0.0444 - root_mean_squared_error: 0.0669 - val_loss: 0.0049 - val_mean_absolute_error: 0.0484 - val_root_mean_squared_error: 0.0700
# Epoch 51/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0050 - mean_absolute_error: 0.0444 - root_mean_squared_error: 0.0706 - val_loss: 0.0050 - val_mean_absolute_error: 0.0483 - val_root_mean_squared_error: 0.0706
# Epoch 52/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0054 - mean_absolute_error: 0.0461 - root_mean_squared_error: 0.0735 - val_loss: 0.0049 - val_mean_absolute_error: 0.0491 - val_root_mean_squared_error: 0.0697
# Epoch 53/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0051 - mean_absolute_error: 0.0442 - root_mean_squared_error: 0.0714 - val_loss: 0.0046 - val_mean_absolute_error: 0.0477 - val_root_mean_squared_error: 0.0675
# Epoch 54/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0039 - mean_absolute_error: 0.0436 - root_mean_squared_error: 0.0627 - val_loss: 0.0046 - val_mean_absolute_error: 0.0493 - val_root_mean_squared_error: 0.0677
# Epoch 55/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0053 - mean_absolute_error: 0.0450 - root_mean_squared_error: 0.0727 - val_loss: 0.0045 - val_mean_absolute_error: 0.0481 - val_root_mean_squared_error: 0.0674
# Epoch 56/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0039 - mean_absolute_error: 0.0411 - root_mean_squared_error: 0.0625 - val_loss: 0.0048 - val_mean_absolute_error: 0.0497 - val_root_mean_squared_error: 0.0689
# Epoch 57/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0056 - mean_absolute_error: 0.0461 - root_mean_squared_error: 0.0751 - val_loss: 0.0046 - val_mean_absolute_error: 0.0486 - val_root_mean_squared_error: 0.0678
# Epoch 58/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0049 - mean_absolute_error: 0.0447 - root_mean_squared_error: 0.0702 - val_loss: 0.0044 - val_mean_absolute_error: 0.0482 - val_root_mean_squared_error: 0.0662
# Epoch 59/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0050 - mean_absolute_error: 0.0449 - root_mean_squared_error: 0.0710 - val_loss: 0.0045 - val_mean_absolute_error: 0.0499 - val_root_mean_squared_error: 0.0672
# Epoch 60/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0055 - mean_absolute_error: 0.0459 - root_mean_squared_error: 0.0739 - val_loss: 0.0043 - val_mean_absolute_error: 0.0467 - val_root_mean_squared_error: 0.0658
# Epoch 61/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0048 - mean_absolute_error: 0.0451 - root_mean_squared_error: 0.0691 - val_loss: 0.0046 - val_mean_absolute_error: 0.0485 - val_root_mean_squared_error: 0.0678
# Epoch 62/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0045 - mean_absolute_error: 0.0437 - root_mean_squared_error: 0.0670 - val_loss: 0.0045 - val_mean_absolute_error: 0.0463 - val_root_mean_squared_error: 0.0675
# Epoch 63/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0050 - mean_absolute_error: 0.0445 - root_mean_squared_error: 0.0709 - val_loss: 0.0046 - val_mean_absolute_error: 0.0497 - val_root_mean_squared_error: 0.0682
# Epoch 64/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0060 - mean_absolute_error: 0.0477 - root_mean_squared_error: 0.0775 - val_loss: 0.0046 - val_mean_absolute_error: 0.0458 - val_root_mean_squared_error: 0.0677
# Epoch 65/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0043 - mean_absolute_error: 0.0428 - root_mean_squared_error: 0.0656 - val_loss: 0.0050 - val_mean_absolute_error: 0.0503 - val_root_mean_squared_error: 0.0704
# Epoch 66/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0045 - mean_absolute_error: 0.0441 - root_mean_squared_error: 0.0669 - val_loss: 0.0046 - val_mean_absolute_error: 0.0461 - val_root_mean_squared_error: 0.0679
# Epoch 67/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0047 - mean_absolute_error: 0.0450 - root_mean_squared_error: 0.0685 - val_loss: 0.0047 - val_mean_absolute_error: 0.0508 - val_root_mean_squared_error: 0.0683
# Epoch 68/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0053 - mean_absolute_error: 0.0458 - root_mean_squared_error: 0.0726 - val_loss: 0.0042 - val_mean_absolute_error: 0.0456 - val_root_mean_squared_error: 0.0648
# Epoch 69/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0038 - mean_absolute_error: 0.0409 - root_mean_squared_error: 0.0619 - val_loss: 0.0045 - val_mean_absolute_error: 0.0495 - val_root_mean_squared_error: 0.0668
# Epoch 70/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0045 - mean_absolute_error: 0.0425 - root_mean_squared_error: 0.0670 - val_loss: 0.0043 - val_mean_absolute_error: 0.0453 - val_root_mean_squared_error: 0.0654
# Epoch 71/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0049 - mean_absolute_error: 0.0430 - root_mean_squared_error: 0.0697 - val_loss: 0.0042 - val_mean_absolute_error: 0.0448 - val_root_mean_squared_error: 0.0651
# Epoch 72/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0051 - mean_absolute_error: 0.0446 - root_mean_squared_error: 0.0712 - val_loss: 0.0058 - val_mean_absolute_error: 0.0499 - val_root_mean_squared_error: 0.0762
# Epoch 73/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0052 - mean_absolute_error: 0.0430 - root_mean_squared_error: 0.0722 - val_loss: 0.0053 - val_mean_absolute_error: 0.0489 - val_root_mean_squared_error: 0.0725
# Epoch 74/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0055 - mean_absolute_error: 0.0452 - root_mean_squared_error: 0.0743 - val_loss: 0.0045 - val_mean_absolute_error: 0.0458 - val_root_mean_squared_error: 0.0669
# Epoch 75/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0052 - mean_absolute_error: 0.0431 - root_mean_squared_error: 0.0718 - val_loss: 0.0043 - val_mean_absolute_error: 0.0449 - val_root_mean_squared_error: 0.0655
# Epoch 76/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0046 - mean_absolute_error: 0.0431 - root_mean_squared_error: 0.0675 - val_loss: 0.0044 - val_mean_absolute_error: 0.0466 - val_root_mean_squared_error: 0.0662
# Epoch 77/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0052 - mean_absolute_error: 0.0435 - root_mean_squared_error: 0.0718 - val_loss: 0.0038 - val_mean_absolute_error: 0.0455 - val_root_mean_squared_error: 0.0618
# Epoch 78/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0042 - mean_absolute_error: 0.0420 - root_mean_squared_error: 0.0652 - val_loss: 0.0040 - val_mean_absolute_error: 0.0435 - val_root_mean_squared_error: 0.0634
# Epoch 79/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0050 - mean_absolute_error: 0.0439 - root_mean_squared_error: 0.0706 - val_loss: 0.0038 - val_mean_absolute_error: 0.0466 - val_root_mean_squared_error: 0.0616
# Epoch 80/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0041 - mean_absolute_error: 0.0432 - root_mean_squared_error: 0.0639 - val_loss: 0.0043 - val_mean_absolute_error: 0.0441 - val_root_mean_squared_error: 0.0655
# Epoch 81/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0056 - mean_absolute_error: 0.0476 - root_mean_squared_error: 0.0745 - val_loss: 0.0045 - val_mean_absolute_error: 0.0526 - val_root_mean_squared_error: 0.0668
# Epoch 82/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0072 - mean_absolute_error: 0.0500 - root_mean_squared_error: 0.0848 - val_loss: 0.0046 - val_mean_absolute_error: 0.0456 - val_root_mean_squared_error: 0.0678
# Epoch 83/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0051 - mean_absolute_error: 0.0444 - root_mean_squared_error: 0.0714 - val_loss: 0.0054 - val_mean_absolute_error: 0.0493 - val_root_mean_squared_error: 0.0732
# Epoch 84/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0053 - mean_absolute_error: 0.0452 - root_mean_squared_error: 0.0729 - val_loss: 0.0034 - val_mean_absolute_error: 0.0416 - val_root_mean_squared_error: 0.0583
# Epoch 85/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0051 - mean_absolute_error: 0.0458 - root_mean_squared_error: 0.0711 - val_loss: 0.0033 - val_mean_absolute_error: 0.0412 - val_root_mean_squared_error: 0.0574
# Epoch 86/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0039 - mean_absolute_error: 0.0421 - root_mean_squared_error: 0.0624 - val_loss: 0.0057 - val_mean_absolute_error: 0.0459 - val_root_mean_squared_error: 0.0753
# Epoch 87/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0045 - mean_absolute_error: 0.0434 - root_mean_squared_error: 0.0673 - val_loss: 0.0044 - val_mean_absolute_error: 0.0436 - val_root_mean_squared_error: 0.0662
# Epoch 88/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0041 - mean_absolute_error: 0.0417 - root_mean_squared_error: 0.0637 - val_loss: 0.0037 - val_mean_absolute_error: 0.0430 - val_root_mean_squared_error: 0.0607
# Epoch 89/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0043 - mean_absolute_error: 0.0419 - root_mean_squared_error: 0.0656 - val_loss: 0.0032 - val_mean_absolute_error: 0.0414 - val_root_mean_squared_error: 0.0564
# Epoch 90/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0049 - mean_absolute_error: 0.0452 - root_mean_squared_error: 0.0700 - val_loss: 0.0038 - val_mean_absolute_error: 0.0463 - val_root_mean_squared_error: 0.0617
# Epoch 91/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0052 - mean_absolute_error: 0.0433 - root_mean_squared_error: 0.0722 - val_loss: 0.0030 - val_mean_absolute_error: 0.0404 - val_root_mean_squared_error: 0.0552
# Epoch 92/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0040 - mean_absolute_error: 0.0431 - root_mean_squared_error: 0.0635 - val_loss: 0.0036 - val_mean_absolute_error: 0.0464 - val_root_mean_squared_error: 0.0598
# Epoch 93/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0038 - mean_absolute_error: 0.0437 - root_mean_squared_error: 0.0614 - val_loss: 0.0031 - val_mean_absolute_error: 0.0394 - val_root_mean_squared_error: 0.0554
# Epoch 94/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0045 - mean_absolute_error: 0.0457 - root_mean_squared_error: 0.0668 - val_loss: 0.0035 - val_mean_absolute_error: 0.0442 - val_root_mean_squared_error: 0.0587
# Epoch 95/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0044 - mean_absolute_error: 0.0443 - root_mean_squared_error: 0.0660 - val_loss: 0.0027 - val_mean_absolute_error: 0.0381 - val_root_mean_squared_error: 0.0523
# Epoch 96/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0041 - mean_absolute_error: 0.0409 - root_mean_squared_error: 0.0637 - val_loss: 0.0040 - val_mean_absolute_error: 0.0449 - val_root_mean_squared_error: 0.0634
# Epoch 97/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0040 - mean_absolute_error: 0.0421 - root_mean_squared_error: 0.0635 - val_loss: 0.0028 - val_mean_absolute_error: 0.0388 - val_root_mean_squared_error: 0.0528
# Epoch 98/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0041 - mean_absolute_error: 0.0415 - root_mean_squared_error: 0.0643 - val_loss: 0.0028 - val_mean_absolute_error: 0.0393 - val_root_mean_squared_error: 0.0529
# Epoch 99/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0044 - mean_absolute_error: 0.0408 - root_mean_squared_error: 0.0660 - val_loss: 0.0030 - val_mean_absolute_error: 0.0397 - val_root_mean_squared_error: 0.0546
# Epoch 100/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0040 - mean_absolute_error: 0.0425 - root_mean_squared_error: 0.0636 - val_loss: 0.0039 - val_mean_absolute_error: 0.0421 - val_root_mean_squared_error: 0.0628
# Epoch 101/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0037 - mean_absolute_error: 0.0406 - root_mean_squared_error: 0.0612 - val_loss: 0.0039 - val_mean_absolute_error: 0.0417 - val_root_mean_squared_error: 0.0624
# Epoch 102/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0056 - mean_absolute_error: 0.0438 - root_mean_squared_error: 0.0751 - val_loss: 0.0039 - val_mean_absolute_error: 0.0437 - val_root_mean_squared_error: 0.0628
# Epoch 103/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0039 - mean_absolute_error: 0.0414 - root_mean_squared_error: 0.0622 - val_loss: 0.0070 - val_mean_absolute_error: 0.0483 - val_root_mean_squared_error: 0.0835
# Epoch 104/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0038 - mean_absolute_error: 0.0411 - root_mean_squared_error: 0.0615 - val_loss: 0.0037 - val_mean_absolute_error: 0.0412 - val_root_mean_squared_error: 0.0605
# Epoch 105/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0037 - mean_absolute_error: 0.0402 - root_mean_squared_error: 0.0612 - val_loss: 0.0040 - val_mean_absolute_error: 0.0427 - val_root_mean_squared_error: 0.0635
# Epoch 106/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0040 - mean_absolute_error: 0.0417 - root_mean_squared_error: 0.0634 - val_loss: 0.0053 - val_mean_absolute_error: 0.0455 - val_root_mean_squared_error: 0.0727
# Epoch 107/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0032 - mean_absolute_error: 0.0396 - root_mean_squared_error: 0.0567 - val_loss: 0.0038 - val_mean_absolute_error: 0.0422 - val_root_mean_squared_error: 0.0617
# Epoch 108/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0044 - mean_absolute_error: 0.0390 - root_mean_squared_error: 0.0663 - val_loss: 0.0026 - val_mean_absolute_error: 0.0373 - val_root_mean_squared_error: 0.0513
# Epoch 109/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0043 - mean_absolute_error: 0.0420 - root_mean_squared_error: 0.0658 - val_loss: 0.0029 - val_mean_absolute_error: 0.0387 - val_root_mean_squared_error: 0.0538
# Epoch 110/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0057 - mean_absolute_error: 0.0449 - root_mean_squared_error: 0.0753 - val_loss: 0.0033 - val_mean_absolute_error: 0.0401 - val_root_mean_squared_error: 0.0577
# Epoch 111/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0048 - mean_absolute_error: 0.0428 - root_mean_squared_error: 0.0690 - val_loss: 0.0028 - val_mean_absolute_error: 0.0368 - val_root_mean_squared_error: 0.0528
# Epoch 112/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0047 - mean_absolute_error: 0.0446 - root_mean_squared_error: 0.0684 - val_loss: 0.0043 - val_mean_absolute_error: 0.0419 - val_root_mean_squared_error: 0.0656
# Epoch 113/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0040 - mean_absolute_error: 0.0431 - root_mean_squared_error: 0.0631 - val_loss: 0.0037 - val_mean_absolute_error: 0.0402 - val_root_mean_squared_error: 0.0612
# Epoch 114/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0042 - mean_absolute_error: 0.0417 - root_mean_squared_error: 0.0647 - val_loss: 0.0025 - val_mean_absolute_error: 0.0361 - val_root_mean_squared_error: 0.0504
# Epoch 115/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0039 - mean_absolute_error: 0.0420 - root_mean_squared_error: 0.0625 - val_loss: 0.0031 - val_mean_absolute_error: 0.0393 - val_root_mean_squared_error: 0.0557
# Epoch 116/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0039 - mean_absolute_error: 0.0421 - root_mean_squared_error: 0.0626 - val_loss: 0.0051 - val_mean_absolute_error: 0.0439 - val_root_mean_squared_error: 0.0713
# Epoch 117/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0043 - mean_absolute_error: 0.0436 - root_mean_squared_error: 0.0659 - val_loss: 0.0028 - val_mean_absolute_error: 0.0382 - val_root_mean_squared_error: 0.0527
# Epoch 118/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0040 - mean_absolute_error: 0.0416 - root_mean_squared_error: 0.0630 - val_loss: 0.0036 - val_mean_absolute_error: 0.0408 - val_root_mean_squared_error: 0.0602
# Epoch 119/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0038 - mean_absolute_error: 0.0409 - root_mean_squared_error: 0.0617 - val_loss: 0.0061 - val_mean_absolute_error: 0.0458 - val_root_mean_squared_error: 0.0783
# Epoch 120/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0047 - mean_absolute_error: 0.0421 - root_mean_squared_error: 0.0688 - val_loss: 0.0036 - val_mean_absolute_error: 0.0407 - val_root_mean_squared_error: 0.0596
# Epoch 121/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0032 - mean_absolute_error: 0.0386 - root_mean_squared_error: 0.0565 - val_loss: 0.0042 - val_mean_absolute_error: 0.0433 - val_root_mean_squared_error: 0.0649
# Epoch 122/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0040 - mean_absolute_error: 0.0420 - root_mean_squared_error: 0.0635 - val_loss: 0.0029 - val_mean_absolute_error: 0.0391 - val_root_mean_squared_error: 0.0536
# Epoch 123/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0036 - mean_absolute_error: 0.0408 - root_mean_squared_error: 0.0599 - val_loss: 0.0032 - val_mean_absolute_error: 0.0406 - val_root_mean_squared_error: 0.0567
# Epoch 124/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0033 - mean_absolute_error: 0.0410 - root_mean_squared_error: 0.0575 - val_loss: 0.0038 - val_mean_absolute_error: 0.0406 - val_root_mean_squared_error: 0.0613
# Epoch 125/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0034 - mean_absolute_error: 0.0394 - root_mean_squared_error: 0.0587 - val_loss: 0.0043 - val_mean_absolute_error: 0.0428 - val_root_mean_squared_error: 0.0657
# Epoch 126/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0043 - mean_absolute_error: 0.0420 - root_mean_squared_error: 0.0653 - val_loss: 0.0055 - val_mean_absolute_error: 0.0456 - val_root_mean_squared_error: 0.0741
# Epoch 127/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0036 - mean_absolute_error: 0.0404 - root_mean_squared_error: 0.0604 - val_loss: 0.0031 - val_mean_absolute_error: 0.0396 - val_root_mean_squared_error: 0.0560
# Epoch 128/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0036 - mean_absolute_error: 0.0406 - root_mean_squared_error: 0.0602 - val_loss: 0.0036 - val_mean_absolute_error: 0.0398 - val_root_mean_squared_error: 0.0598
# Epoch 129/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0046 - mean_absolute_error: 0.0436 - root_mean_squared_error: 0.0676 - val_loss: 0.0039 - val_mean_absolute_error: 0.0399 - val_root_mean_squared_error: 0.0625
# Epoch 130/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0030 - mean_absolute_error: 0.0379 - root_mean_squared_error: 0.0552 - val_loss: 0.0028 - val_mean_absolute_error: 0.0385 - val_root_mean_squared_error: 0.0526
# Epoch 131/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0035 - mean_absolute_error: 0.0398 - root_mean_squared_error: 0.0595 - val_loss: 0.0030 - val_mean_absolute_error: 0.0378 - val_root_mean_squared_error: 0.0548
# Epoch 132/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0044 - mean_absolute_error: 0.0434 - root_mean_squared_error: 0.0666 - val_loss: 0.0056 - val_mean_absolute_error: 0.0426 - val_root_mean_squared_error: 0.0747
# Epoch 133/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0040 - mean_absolute_error: 0.0412 - root_mean_squared_error: 0.0634 - val_loss: 0.0035 - val_mean_absolute_error: 0.0387 - val_root_mean_squared_error: 0.0593
# Epoch 134/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0056 - mean_absolute_error: 0.0447 - root_mean_squared_error: 0.0748 - val_loss: 0.0025 - val_mean_absolute_error: 0.0356 - val_root_mean_squared_error: 0.0504

# %%
# Plot the training and validation accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('MAE')
plt.ylabel('Mean absolute error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'])
plt.show()

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MSE')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
# Predict SOC using test dataset
Ypred = model.predict(Xtest)
Ytest = np.array([sublist[::5] for sublist in Ytest])
Ypred = Ypred * (max-min) + min
Ytest = Ytest * (max-min) + min
print('shape', Ypred.shape)
print(Ypred[:10], np.max(Ypred), np.min(Ypred))
# Out:
# 3/3 [==============================] - 0s 6ms/step
# shape (96, 1)
# [[ 8.98865  ]
#  [11.488022 ]
#  [10.53924  ]
#  [10.548157 ]
#  [ 8.28095  ]
#  [11.268655 ]
#  [46.48499  ]
#  [ 6.855706 ]
#  [ 6.3408804]
#  [ 9.762946 ]] 48.59039 3.6798005
# 2023-07-06 12:06:40.110596: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [96,5,17]
# 	 [[{{node Placeholder/_10}}]]
# 2023-07-06 12:06:40.111023: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [96,5,17]
# 	 [[{{node Placeholder/_10}}]]

# %%
# Calculate the metric values
mse = mean_squared_error(Ytest, Ypred)
print("RMSE", math.sqrt(mse))
mae = mean_absolute_error(Ytest, Ypred)
print("MAE", mae)
R_square = r2_score(Ytest, Ypred) 
print('Coefficient of Determination', R_square)
# Out:
# RMSE 8.142400911829743
# MAE 4.9941156718095145
# Coefficient of Determination 0.5514418881092358

# %%
# Plot the predicted SOC against the observed SOC
scatterplot=sns.scatterplot(x=np.squeeze(Ypred), y=np.squeeze(Ytest))
z = np.polyfit(np.squeeze(Ypred), np.squeeze(Ytest), 1)  #Least squares polynomial fit.
p = np.poly1d(z)                           #A one-dimensional polynomial class.
scatterplot.plot(np.squeeze(Ytest), p(np.squeeze(Ytest)), "r--", label='trend line')
# plt.xlim([-0.1, 1.1])
# plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel("Predicted SOC")
plt.ylabel("Observed SOC")
plt.show()

# %%
# Save the trained model
model.save(os.getcwd() + '/LSTM', save_format='tf')

# %%
# Check if the model can be properly loaded
model = tf.keras.models.load_model(os.getcwd() + '/LSTM')
